# %%
import pandas as pd

df = pd.read_csv("../data/posts.csv")
print(df.shape)
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("../data/posts.csv")
#       4 print(df.shape)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/eshaannanavare/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/eshaannanavare/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp311-cp311-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 6.5 MB/s  0:00:01 eta 0:00:01m
# Downloading numpy-2.4.3-cp311-cp311-macosx_14_0_arm64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.0 MB/s  0:00:02 eta 0:00:01m
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.3 pandas-3.0.1
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

df = pd.read_csv("../data/posts.csv")
print(df.shape)
print(df.head())
# Out:
# (500, 6)
#                                     title  \
# 0  Isn’t RE giving user manuals nowadays?
# 1           Sunday Ride To The Lakeside 💕
# 2        Interceptor 650 for tell riders?
# 3              Aew 103 interceptor 650 E5
# 4               Free Helmet on Delivery ?
#
#                                                 text  score  num_comments  \
# 0  Recently got delivery of classic 350 in Bangal...      1             1
# 1                                                NaN      2             0
# 2  Hi. I am considering getting the interceptor. ...      1             1
# 3  I just installed these exhausts, I expected to...      1             1
# 4  Guys i came to know we get a helmet on deliver...      1             2
#
#     created_utc                                                url
# 0  1.774200e+09  https://www.reddit.com/r/royalenfield/comments...
# 1  1.774200e+09               https://i.redd.it/begy5pcasmqg1.jpeg
# 2  1.774200e+09  https://www.reddit.com/r/royalenfield/comments...
# 3  1.774199e+09  https://www.reddit.com/r/royalenfield/comments...
# 4  1.774199e+09  https://www.reddit.com/r/royalenfield/comments...

# %%
print("Missing values:\n", df.isnull().sum())
print("\nEmpty text posts:", (df['text'] == '').sum())
print("\nScore range:", df['score'].min(), "to", df['score'].max())
print("\nAvg comments per post:", df['num_comments'].mean().round(2))
# Out:
# Missing values:
#  title            0
# text            90
# score            0
# num_comments     0
# created_utc      0
# url              0
# dtype: int64
#
# Empty text posts: 0
#
# Score range: 0 to 4636
#
# Avg comments per post: 12.76

# %%
# fill missing text with the title so we don't lose those 90 posts
df['text'] = df['text'].fillna(df['title'])

# convert unix timestamp to readable date
df['date'] = pd.to_datetime(df['created_utc'], unit='s')

# check result
print(df[['title', 'text', 'date']].head())
print("\nMissing text after fix:", df['text'].isnull().sum())
# Out:
#                                     title  \
# 0  Isn’t RE giving user manuals nowadays?
# 1           Sunday Ride To The Lakeside 💕
# 2        Interceptor 650 for tell riders?
# 3              Aew 103 interceptor 650 E5
# 4               Free Helmet on Delivery ?
#
#                                                 text                date
# 0  Recently got delivery of classic 350 in Bangal... 2026-03-22 17:25:39
# 1                      Sunday Ride To The Lakeside 💕 2026-03-22 17:24:30
# 2  Hi. I am considering getting the interceptor. ... 2026-03-22 17:17:45
# 3  I just installed these exhausts, I expected to... 2026-03-22 17:00:27
# 4  Guys i came to know we get a helmet on deliver... 2026-03-22 16:59:22
#
# Missing text after fix: 0

# %%
df.to_csv("../data/posts_cleaned.csv", index=False)
print("Saved cleaned data")
# Out:
# Saved cleaned data
